# %% [markdown]
# # Setup packages

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
# from pymer4.models import Lmer
from natsort import natsorted, ns
import glob
import networkx as nx
from scipy.stats import pearsonr

fpath = 'C:/Users/becha/Desktop/Face_meteor_analysis'

# %% [markdown]
# ## Loading data for analysis

# %%
datalist = natsorted(glob.glob(os.path.join(fpath,'Data', 'preprocessed_data', 'preprocessed_data', "v8","*")))
len(datalist)
print('There are',len(datalist),'groups for v8.')
# Out:
# There are 51 groups for v8.

# %%
lst = []

def loop_directory(directory: str):
    '''Loop files in the directory'''

    for filename in os.listdir(directory):
            if filename.endswith(".csv"):
                file_directory = os.path.join(directory, filename)
                lst.append(file_directory)
                pd.read_csv(file_directory)
                
                
            else:
                continue
#     print(lst)

# %% [markdown]
# ### The data of games

# %%
loop_directory('C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8')

# %%
lst
# print(len(lst))
# Out:
# ['C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_136_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_137_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_138_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_139_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_140_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_141_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_142_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_143_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_144_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_145_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_146_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_147_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_148_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_149_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_150_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_151_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_152_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_186_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_187_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_188_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_208_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_209_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_211_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_212_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_213_v8.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v8\\group_214_v8.csv']

# %%
# df0 = pd.read_csv(lst[0])
# df1 = pd.read_csv(lst[1])
# df2 = pd.read_csv(lst[2])
# df3 = pd.read_csv(lst[3])
# df4 = pd.read_csv(lst[4])
# df5 = pd.read_csv(lst[5])

datlst = []
for i in range(0, len(lst)):
    datlst.append("df" + str(i))
    globals()["df" + str(i)] = pd.read_csv(lst[i])

# %%
datlst
# Out:
# ['df0',
#  'df1',
#  'df2',
#  'df3',
#  'df4',
#  'df5',
#  'df6',
#  'df7',
#  'df8',
#  'df9',
#  'df10',
#  'df11',
#  'df12',
#  'df13',
#  'df14',
#  'df15',
#  'df16',
#  'df17',
#  'df18',
#  'df19',
#  'df20',
#  'df21',
#  'df22',
#  'df23',
#  'df24',
#  'df25',
#  'df26',
#  'df27',
#  'df28',
#  'df29',
#  'df30',
#  'df31',
#  'df32',
#  'df33',
#  'df34',
#  'df35',
#  'df36',
#  'df37',
#  'df38',
#  'df39',
#  'df40',
#  'df41',
#  'df42',
#  'df43',
#  'df44',
#  'df45',
#  'df46',
#  'df47',
#  'df48',
#  'df49',
#  'df50']

# %% [markdown]
# ### The data of ratings

# %%
lst_dislike = []

def loop_directory(directory: str):
    '''Loop files in the directory'''

    for filename in os.listdir(directory):
            if filename.endswith(".csv"):
                file_directory = os.path.join(directory, filename)
                lst_dislike.append(file_directory)
                pd.read_csv(file_directory)
                
                
            else:
                continue

# %%
loop_directory('C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8')

# %%
lst_dislike
# print(len(lst_dislike))
# Out:
# ['C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID136.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID137.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID138.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID211.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID212.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID213.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v8\\rating_GroupID214.csv']

# %%
datlst_dislike = []
for i in range(0, len(lst)):
    datlst_dislike.append("df_dislike" + str(i))
    globals()["df_dislike" + str(i)] = pd.read_csv(lst_dislike[i])
datlst_dislike
# Out:
# ['df_dislike0',
#  'df_dislike1',
#  'df_dislike2',
#  'df_dislike3',
#  'df_dislike4',
#  'df_dislike5',
#  'df_dislike6',
#  'df_dislike7',
#  'df_dislike8',
#  'df_dislike9',
#  'df_dislike10',
#  'df_dislike11',
#  'df_dislike12',
#  'df_dislike13',
#  'df_dislike14',
#  'df_dislike15',
#  'df_dislike16',
#  'df_dislike17',
#  'df_dislike18',
#  'df_dislike19',
#  'df_dislike20',
#  'df_dislike21',
#  'df_dislike22',
#  'df_dislike23',
#  'df_dislike24',
#  'df_dislike25',
#  'df_dislike26',
#  'df_dislike27',
#  'df_dislike28',
#  'df_dislike29',
#  'df_dislike30',
#  'df_dislike31',
#  'df_dislike32',
#  'df_dislike33',
#  'df_dislike34',
#  'df_dislike35',
#  'df_dislike36',
#  'df_dislike37',
#  'df_dislike38',
#  'df_dislike39',
#  'df_dislike40',
#  'df_dislike41',
#  'df_dislike42',
#  'df_dislike43',
#  'df_dislike44',
#  'df_dislike45',
#  'df_dislike46',
#  'df_dislike47',
#  'df_dislike48',
#  'df_dislike49',
#  'df_dislike50']

# %% [markdown]
# # The correlation between round 10 and dislike

# %% [markdown]
# ## The performance of the dictator in round 10

# %%
## 取round 10的島主的pgg_receive
dictator_pgg = []
for i in range(0, len(lst)):
    dictator_pgg.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[9]['pgg_receive'])

# print(dictator_pgg)
# print(len(dictator_pgg))

# %%
## 取round 10的所有人的pgg_receive
all_pgg = []
for i in range(0,len(lst)):
    all_pgg.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 10]['pgg_receive']))

# print(all_pgg)
# print(len(all_pgg))

# %%
# 計算：v5中島主最後一round pgg表現的顯著程度
ratio_10 = [x/y for x, y in zip(dictator_pgg, all_pgg)]

# %%
df_ratio = pd.DataFrame({"group": datlst, "dictator's pgg receive": dictator_pgg, "all player's pgg receive": all_pgg, "ratio": ratio_10})

# %%
df_ratio
# Out:
#    group  dictator's pgg receive  all player's pgg receive     ratio
# 0    df0                    1000                      1000  1.000000
# 1    df1                     132                       518  0.254826
# 2    df2                     197                       325  0.606154
# 3    df3                     250                       250  1.000000
# 4    df4                     153                       593  0.258010
# 5    df5                     530                       750  0.706667
# 6    df6                     263                       813  0.323493
# 7    df7                     697                      1000  0.697000
# 8    df8                     250                      1000  0.250000
# 9    df9                     250                      1000  0.250000
# 10  df10                      45                       363  0.123967
# 11  df11                     235                      1000  0.235000
# 12  df12                     330                      1000  0.330000
# 13  df13                     728                       728  1.000000
# 14  df14                     250                       918  0.272331
# 15  df15                     555                      1000  0.555000
# 16  df16                     301                       610  0.493443
# 17  df17                     228                       905  0.251934
# 18  df18                     815                       815  1.000000
# 19  df19                     575                       818  0.702934
# 20  df20                     152                       500  0.304000
# 21  df21                     250                       875  0.285714
# 22  df22                     270                       750  0.360000
# 23  df23                     278                       675  0.411852
# 24  df24                       0                      1000  0.000000
# 25  df25                      29                        55  0.527273
# 26  df26                     251                       825  0.304242
# 27  df27                     238                       500  0.476000
# 28  df28                     250                       875  0.285714
# 29  df29                     222                       685  0.324088
# 30  df30                     100                       283  0.353357
# 31  df31                     413                       413  1.000000
# 32  df32                     290                       630  0.460317
# 33  df33                     220                       850  0.258824
# 34  df34                     288                       800  0.360000
# 35  df35                     298                       500  0.596000
# 36  df36                     334                       675  0.494815
# 37  df37                     250                       750  0.333333
# 38  df38                      90                       400  0.225000
# 39  df39                     250                      1000  0.250000
# 40  df40                     250                       800  0.312500
# 41  df41                     115                       265  0.433962
# 42  df42                     251                      1000  0.251000
# 43  df43                     250                      1000  0.250000
# 44  df44                     250                      1000  0.250000
# 45  df45                     250                      1000  0.250000
# 46  df46                     875                       875  1.000000
# 47  df47                     898                       898  1.000000
# 48  df48                     650                       950  0.684211
# 49  df49                     300                       500  0.600000
# 50  df50                     257                       875  0.293714

# %% [markdown]
# ## The degree of dislike of the dictator

# %%
# 先以df_dislike0為例
dislike = []
for i in range(0,len(lst)):
    dislike.append(np.mean(globals()["df_dislike" + str(i)]['liking_p1'][1:]))

# print(dislike)
# len(dislike)

# %%
df_ratio['dislike'] = dislike

# %%
df_ratio
# Out:
#    group  dictator's pgg receive  all player's pgg receive     ratio  \
# 0    df0                    1000                      1000  1.000000
# 1    df1                     132                       518  0.254826
# 2    df2                     197                       325  0.606154
# 3    df3                     250                       250  1.000000
# 4    df4                     153                       593  0.258010
# 5    df5                     530                       750  0.706667
# 6    df6                     263                       813  0.323493
# 7    df7                     697                      1000  0.697000
# 8    df8                     250                      1000  0.250000
# 9    df9                     250                      1000  0.250000
# 10  df10                      45                       363  0.123967
# 11  df11                     235                      1000  0.235000
# 12  df12                     330                      1000  0.330000
# 13  df13                     728                       728  1.000000
# 14  df14                     250                       918  0.272331
# 15  df15                     555                      1000  0.555000
# 16  df16                     301                       610  0.493443
# 17  df17                     228                       905  0.251934
# 18  df18                     815                       815  1.000000
# 19  df19                     575                       818  0.702934
# 20  df20                     152                       500  0.304000
# 21  df21                     250                       875  0.285714
# 22  df22                     270                       750  0.360000
# 23  df23                     278                       675  0.411852
# 24  df24                       0                      1000  0.000000
# 25  df25                      29                        55  0.527273
# 26  df26                     251                       825  0.304242
# 27  df27                     238                       500  0.476000
# 28  df28                     250                       875  0.285714
# 29  df29                     222                       685  0.324088
# 30  df30                     100                       283  0.353357
# 31  df31                     413                       413  1.000000
# 32  df32                     290                       630  0.460317
# 33  df33                     220                       850  0.258824
# 34  df34                     288                       800  0.360000
# 35  df35                     298                       500  0.596000
# 36  df36                     334                       675  0.494815
# 37  df37                     250                       750  0.333333
# 38  df38                      90                       400  0.225000
# 39  df39                     250                      1000  0.250000
# 40  df40                     250                       800  0.312500
# 41  df41                     115                       265  0.433962
# 42  df42                     251                      1000  0.251000
# 43  df43                     250                      1000  0.250000
# 44  df44                     250                      1000  0.250000
# 45  df45                     250                      1000  0.250000
# 46  df46                     875                       875  1.000000
# 47  df47                     898                       898  1.000000
# 48  df48                     650                       950  0.684211
# 49  df49                     300                       500  0.600000
# 50  df50                     257                       875  0.293714
#
#       dislike
# 0    0.000000
# 1   44.333333
# 2   29.000000
# 3   57.333333
# 4   50.333333
# 5    5.333333
# 6   60.333333
# 7   17.000000
# 8   97.333333
# 9   82.666667
# 10  58.000000
# 11  65.333333
# 12  39.666667
# 13  43.333333
# 14  67.333333
# 15  33.333333
# 16  14.000000
# 17  45.000000
# 18  14.666667
# 19  40.666667
# 20  64.000000
# 21  78.666667
# 22  66.333333
# 23  33.333333
# 24  92.666667
# 25  34.333333
# 26  64.333333
# 27  26.333333
# 28  97.333333
# 29  17.000000
# 30  27.666667
# 31  18.000000
# 32  67.666667
# 33  48.000000
# 34  63.666667
# 35   6.666667
# 36  57.000000
# 37  66.666667
# 38  54.666667
# 39  94.666667
# 40  68.000000
# 41  60.000000
# 42  84.333333
# 43  77.666667
# 44  74.333333
# 45  98.666667
# 46  26.666667
# 47   4.333333
# 48  16.666667
# 49  26.333333
# 50  66.333333

# %% [markdown]
# ## The correlation

# %%
my_rho = np.corrcoef(ratio_10, dislike)

# print(my_rho)
print("The value of correlation is",my_rho[0][1],'.')
# Out:
# The value of correlation is -0.683887909213658 .

# %% [markdown]
# ## Visualization

# %%
ax = sns.regplot(x= ratio_10, y=dislike, data=df_ratio, ci=None)
ax.set_title("The score of being liked of the dictator vs. The pgg_receive in round 10")
ax.set_xlabel("The ratio of pgg_receive of the dictator in round 10")
ax.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 9 and dislike

# %% [markdown]
# ## The performance of the dictator in round 9

# %%
## 取round 9的島主的pgg_receive
dictator_pgg_9 = []
for i in range(0, len(lst)):
    dictator_pgg_9.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[8]['pgg_receive'])

# print(dictator_pgg_9)
# print(len(dictator_pgg_9))

# %%
## 取round 9的所有人的pgg_receive
all_pgg_9 = []
for i in range(0,len(lst)):
    all_pgg_9.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 9]['pgg_receive']))

# print(all_pgg_9)
# print(len(all_pgg_9))

# %%
# 計算：v5中島主round 9 pgg表現的顯著程度
ratio_9 = [x/y for x, y in zip(dictator_pgg_9, all_pgg_9)]
# type(ratio)

# %%
df_ratio_9 = pd.DataFrame({"group": datlst, "dictator's pgg receive": dictator_pgg_9, "all player's pgg receive": all_pgg_9, "ratio": ratio_9})

# %%
df_ratio_9
# Out:
#    group  dictator's pgg receive  all player's pgg receive     ratio
# 0    df0                     250                      1000  0.250000
# 1    df1                     123                       495  0.248485
# 2    df2                     270                       538  0.501859
# 3    df3                       0                       475  0.000000
# 4    df4                     154                       613  0.251223
# 5    df5                     422                       875  0.482286
# 6    df6                     260                       850  0.305882
# 7    df7                     250                      1000  0.250000
# 8    df8                     250                       850  0.294118
# 9    df9                     250                      1000  0.250000
# 10  df10                     131                       463  0.282937
# 11  df11                     249                      1000  0.249000
# 12  df12                     251                      1000  0.251000
# 13  df13                     333                       633  0.526066
# 14  df14                     220                       888  0.247748
# 15  df15                     219                       950  0.230526
# 16  df16                     209                       613  0.340946
# 17  df17                     224                       893  0.250840
# 18  df18                     250                       870  0.287356
# 19  df19                     266                       723  0.367911
# 20  df20                     113                       475  0.237895
# 21  df21                     249                       998  0.249499
# 22  df22                     270                       850  0.317647
# 23  df23                     332                       713  0.465638
# 24  df24                     103                      1000  0.103000
# 25  df25                      91                       153  0.594771
# 26  df26                     210                       733  0.286494
# 27  df27                     384                       675  0.568889
# 28  df28                     250                      1000  0.250000
# 29  df29                     254                       775  0.327742
# 30  df30                     140                       555  0.252252
# 31  df31                      50                       213  0.234742
# 32  df32                     301                       723  0.416321
# 33  df33                     234                       850  0.275294
# 34  df34                     325                      1000  0.325000
# 35  df35                     338                       675  0.500741
# 36  df36                     364                       813  0.447724
# 37  df37                     250                       875  0.285714
# 38  df38                      90                       425  0.211765
# 39  df39                     250                      1000  0.250000
# 40  df40                     250                       688  0.363372
# 41  df41                      67                       133  0.503759
# 42  df42                     250                       988  0.253036
# 43  df43                     250                      1000  0.250000
# 44  df44                     250                      1000  0.250000
# 45  df45                     250                      1000  0.250000
# 46  df46                     320                       875  0.365714
# 47  df47                     500                       875  0.571429
# 48  df48                     388                       913  0.424973
# 49  df49                     195                       588  0.331633
# 50  df50                     262                       975  0.268718

# %% [markdown]
# ## The correlation

# %%
my_rho_9 = np.corrcoef(ratio_9, dislike)

# print(my_rho)
print("The value of correlation is",my_rho_9[0][1],'.')
# Out:
# The value of correlation is -0.43423398109432326 .

# %% [markdown]
# ## Visualization

# %%
ax_9 = sns.regplot(x= ratio_9, y=dislike, data=df_ratio_9, ci=None)
ax_9.set_title("The score of being liked of the dictator vs. The pgg_receive in round 9")
ax_9.set_xlabel("The ratio of pgg_receive of the dictator in round 9")
ax_9.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 9 & 10 and dislike

# %% [markdown]
# ## The performance of the dictator in round 9 & 10

# %%
ratio_910 = [(x+y)/2 for x, y in zip(ratio_9, ratio_10)]

# %% [markdown]
# ## The correlation

# %%
my_rho_910 = np.corrcoef(ratio_910, dislike)

print("The value of correlation is",my_rho_910[0][1],'.')
# Out:
# The value of correlation is -0.7221444396907534 .

# %% [markdown]
# # The correlation between round 1-8 and dislike

# %% [markdown]
# ## The performance of the dictator in round 1

# %%
# 取round 1的島主的pgg_receive
dictator_pgg_1 = []
for i in range(0, len(lst)):
    dictator_pgg_1.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[0]['pgg_receive'])

# print(dictator_pgg_1)

# %%
# 取round 1的所有人的pgg_receive
all_pgg_1 = []
for i in range(0,len(lst)):
    all_pgg_1.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 1]['pgg_receive']))

print(all_pgg_1)
# Out:
# [308, 350, 475, 600, 638, 475, 338, 638, 438, 385, 675, 413, 450, 450, 433, 688, 650, 445, 568, 525, 425, 550, 575, 613, 488, 275, 535, 625, 525, 500, 325, 375, 605, 425, 400, 650, 488, 225, 488, 600, 488, 463, 625, 513, 413, 438, 675, 450, 395, 330, 550]

# %%
# 計算：島主在round 1中pgg表現的顯著程度
ratio_1 = [x/y for x, y in zip(dictator_pgg_1, all_pgg_1)]

# %% [markdown]
# ## The performance of the dictator in round 2

# %%
# 取round 2的島主的pgg_receive
dictator_pgg_2 = []
for i in range(0, len(lst)):
    dictator_pgg_2.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[1]['pgg_receive'])
# print(dictator_pgg_2)

# %%
# 取round 2的所有人的pgg_receive
all_pgg_2 = []
for i in range(0,len(lst)):
    all_pgg_2.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 2]['pgg_receive']))

# print(all_pgg_2)

# %%
# 計算：島主在round 2中pgg表現的顯著程度
ratio_2 = [x/y for x, y in zip(dictator_pgg_2, all_pgg_2)]

# %% [markdown]
# ## The performance of the dictator in round 3

# %%
# 取round 3的島主的pgg_receive
dictator_pgg_3 = []
for i in range(0, len(lst)):
    dictator_pgg_3.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[2]['pgg_receive'])
# print(dictator_pgg_3)

# %%
# 取round 3的所有人的pgg_receive
all_pgg_3 = []
for i in range(0,len(lst)):
    all_pgg_3.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 3]['pgg_receive']))

# print(all_pgg_3)

# %%
# 計算：島主在round 3中pgg表現的顯著程度
ratio_3 = [x/y for x, y in zip(dictator_pgg_3, all_pgg_3)]

# %% [markdown]
# ## The performance of the dictator in round 4

# %%
# 取round 4的島主的pgg_receive
dictator_pgg_4 = []
for i in range(0, len(lst)):
    dictator_pgg_4.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[3]['pgg_receive'])
# print(dictator_pgg_4)

# %%
# 取round 4的所有人的pgg_receive
all_pgg_4 = []
for i in range(0,len(lst)):
    all_pgg_4.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 4]['pgg_receive']))

# print(all_pgg_4)

# %%
# 計算：島主在round 4中pgg表現的顯著程度
ratio_4 = [x/y for x, y in zip(dictator_pgg_4, all_pgg_4)]

# %% [markdown]
# ## The performance of the dictator in round 5

# %%
# 取round 5的島主的pgg_receive
dictator_pgg_5 = []
for i in range(0, len(lst)):
    dictator_pgg_5.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[4]['pgg_receive'])
# print(dictator_pgg_5)

# %%
# 取round 5的所有人的pgg_receive
all_pgg_5 = []
for i in range(0,len(lst)):
    all_pgg_5.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 5]['pgg_receive']))

# print(all_pgg_5)

# %%
# 計算：島主在round 5中pgg表現的顯著程度
ratio_5 = [x/y for x, y in zip(dictator_pgg_5, all_pgg_5)]

# %% [markdown]
# ## The performance of the dictator in round 6

# %%
# 取round 6的島主的pgg_receive
dictator_pgg_6 = []
for i in range(0, len(lst)):
    dictator_pgg_6.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[5]['pgg_receive'])
# print(dictator_pgg_6)

# %%
# 取round 6的所有人的pgg_receive
all_pgg_6 = []
for i in range(0,len(lst)):
    all_pgg_6.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 6]['pgg_receive']))

# print(all_pgg_6)

# %%
# 計算：島主在round 6中pgg表現的顯著程度
ratio_6 = [x/y for x, y in zip(dictator_pgg_6, all_pgg_6)]

# %% [markdown]
# ## The performance of the dictator in round 7

# %%
# 取round 7的島主的pgg_receive
dictator_pgg_7 = []
for i in range(0, len(lst)):
    dictator_pgg_7.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[6]['pgg_receive'])
# print(dictator_pgg_7)

# %%
# 取round 7的所有人的pgg_receive
all_pgg_7 = []
for i in range(0,len(lst)):
    all_pgg_7.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 7]['pgg_receive']))

# print(all_pgg_7)

# %%
# 計算：島主在round 7中pgg表現的顯著程度
ratio_7 = [x/y for x, y in zip(dictator_pgg_7, all_pgg_7)]

# %% [markdown]
# ## The performance of the dictator in round 8

# %%
# 取round 8的島主的pgg_receive
dictator_pgg_8 = []
for i in range(0, len(lst)):
    dictator_pgg_8.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[7]['pgg_receive'])
# print(dictator_pgg_8)

# %%
# 取round 8的所有人的pgg_receive
all_pgg_8 = []
for i in range(0,len(lst)):
    all_pgg_8.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 8]['pgg_receive']))

# print(all_pgg_8)

# %%
# 計算：島主在round 8中pgg表現的顯著程度
ratio_8 = [x/y for x, y in zip(dictator_pgg_8, all_pgg_8)]

# %% [markdown]
# ## The performance of the dictator in round 1-8

# %%
df_RD = pd.DataFrame({"group": datlst, "round 1": ratio_1, "round 2": ratio_2, "round 3": ratio_3, "round 4": ratio_4, "round 5": ratio_5, "round 6": ratio_6, "round 7": ratio_7, "round 8": ratio_8})

# %%
mean_RD = []
mean_RD = df_RD[['round 1', 'round 2', 'round 3', 'round 4', 'round 5', 'round 6', 'round 7', 'round 8']].mean(1)

# %%
mean_RD
# Out:
# 0     0.273554
# 1     0.273747
# 2     0.535530
# 3     0.249893
# 4     0.297714
# 5     0.424706
# 6     0.326361
# 7     0.290167
# 8     0.301059
# 9     0.327952
# 10    0.299373
# 11    0.238994
# 12    0.260570
# 13    0.484052
# 14    0.242234
# 15    0.257995
# 16    0.487850
# 17    0.276857
# 18    0.377418
# 19    0.311614
# 20    0.282883
# 21    0.360205
# 22    0.348262
# 23    0.410281
# 24    0.165537
# 25    0.472274
# 26    0.295689
# 27    0.459183
# 28    0.271665
# 29    0.255052
# 30    0.341881
# 31    0.397508
# 32    0.480841
# 33    0.285698
# 34    0.355111
# 35    0.477385
# 36    0.542955
# 37    0.307181
# 38    0.226095
# 39    0.276770
# 40    0.333341
# 41    0.353419
# 42    0.291924
# 43    0.341137
# 44    0.211987
# 45    0.336069
# 46    0.313817
# 47    0.628600
# 48    0.485766
# 49    0.313797
# 50    0.264115
# dtype: float64

# %% [markdown]
# ## The correlation

# %%
df_cor = pd.DataFrame({"ratio of round 1-8":mean_RD,"dislike":dislike})

# %%
# df_cor

# %%
my_rho_1to8 = np.corrcoef(mean_RD, dislike)

# print(my_rho)
print("The value of correlation is",my_rho_1to8[0][1],'.')
# Out:
# The value of correlation is -0.44734131141158645 .

# %% [markdown]
# ## Visualization

# %%
ax_1to8 = sns.regplot(x= mean_RD, y=dislike, data=df_cor, ci=None)
ax_1to8.set_title("The score of being liked of the dictator vs. The pgg_receive in round 1-8")
ax_1to8.set_xlabel("The ratio of pgg_receive of the dictator in round 1-8")
ax_1to8.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 1-10 and dislike

# %%
ratio_1to10 = [(x*8+y*2)/10 for x, y in zip(mean_RD, ratio_910)]

# %%
ratio_1to10
# Out:
# [0.34384281743635203,
#  0.2693285593613868,
#  0.5392254180387359,
#  0.2999142857142857,
#  0.2890941936977981,
#  0.45866039887344234,
#  0.32402641751658245,
#  0.32683393184452547,
#  0.295259222912843,
#  0.31236188511033813,
#  0.2801888964314858,
#  0.23959513170496693,
#  0.2665558617204045,
#  0.539848544684839,
#  0.24579500638438337,
#  0.2849486808844067,
#  0.4737189035694233,
#  0.2717626998021042,
#  0.430669892924694,
#  0.35637604705848,
#  0.28049566926906533,
#  0.3416851484200694,
#  0.34637466671748623,
#  0.4159741505999577,
#  0.14272967152622346,
#  0.49002368040076305,
#  0.2956250173215081,
#  0.47183497225448445,
#  0.27090311022605945,
#  0.2692249068367823,
#  0.3340658718475278,
#  0.4414809163073037,
#  0.47233629468159,
#  0.28197043319902887,
#  0.35258847877611965,
#  0.4915817182776564,
#  0.5286182083750401,
#  0.30764929030015237,
#  0.22455262915869256,
#  0.2714161057092994,
#  0.33426022455376475,
#  0.3765071941812194,
#  0.28394310055633504,
#  0.32290986536223587,
#  0.21958963718851426,
#  0.31885517550622094,
#  0.3876252594412965,
#  0.6600232078006772,
#  0.49953115836064443,
#  0.34420050395455926,
#  0.26753542514637274]

# %% [markdown]
# ## The correlation

# %%
my_rho_1to10 = np.corrcoef(ratio_1to10, dislike)

# print(my_rho)
print("The value of correlation is",my_rho_1to10[0][1],'.')
# Out:
# The value of correlation is -0.5666854839428497 .
