# %% [markdown]
# # Setup packages

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
# from pymer4.models import Lmer
from natsort import natsorted, ns
import glob
import networkx as nx
from scipy.stats import pearsonr

fpath = 'C:/Users/becha/Desktop/Face_meteor_analysis'

# %% [markdown]
# ## Loading data for analysis

# %%
datalist = natsorted(glob.glob(os.path.join(fpath,'Data', 'preprocessed_data', 'preprocessed_data', "v5","*")))
len(datalist)
print('There are',len(datalist),'groups for v5.')
# Out:
# There are 52 groups for v5.

# %%
lst = []

def loop_directory(directory: str):
    '''Loop files in the directory'''

    for filename in os.listdir(directory):
            if filename.endswith(".csv"):
                file_directory = os.path.join(directory, filename)
                lst.append(file_directory)
                pd.read_csv(file_directory)
                
                
            else:
                continue
#     print(lst)

# %% [markdown]
# ### The data of games

# %%
loop_directory('C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5')

# %%
lst
# print(len(lst))
# Out:
# ['C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_100_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_101_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_103_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_104_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_105_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_106_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_107_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_108_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_109_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_110_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_111_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_112_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_113_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_114_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_116_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_117_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_118_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_74_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_75_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_91_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_92_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_93_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_94_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_95_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_96_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_97_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_98_v5.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data/preprocessed_data/v5\\group_99_v5.csv']

# %%
# df0 = pd.read_csv(lst[0])
# df1 = pd.read_csv(lst[1])
# df2 = pd.read_csv(lst[2])
# df3 = pd.read_csv(lst[3])
# df4 = pd.read_csv(lst[4])
# df5 = pd.read_csv(lst[5])

datlst = []
for i in range(0, len(lst)):
    datlst.append("df" + str(i))
    globals()["df" + str(i)] = pd.read_csv(lst[i])

# %%
datlst
# Out:
# ['df0',
#  'df1',
#  'df2',
#  'df3',
#  'df4',
#  'df5',
#  'df6',
#  'df7',
#  'df8',
#  'df9',
#  'df10',
#  'df11',
#  'df12',
#  'df13',
#  'df14',
#  'df15',
#  'df16',
#  'df17',
#  'df18',
#  'df19',
#  'df20',
#  'df21',
#  'df22',
#  'df23',
#  'df24',
#  'df25',
#  'df26',
#  'df27',
#  'df28',
#  'df29',
#  'df30',
#  'df31',
#  'df32',
#  'df33',
#  'df34',
#  'df35',
#  'df36',
#  'df37',
#  'df38',
#  'df39',
#  'df40',
#  'df41',
#  'df42',
#  'df43',
#  'df44',
#  'df45',
#  'df46',
#  'df47',
#  'df48',
#  'df49',
#  'df50',
#  'df51']

# %% [markdown]
# ### The data of ratings

# %%
lst_dislike = []

def loop_directory(directory: str):
    '''Loop files in the directory'''

    for filename in os.listdir(directory):
            if filename.endswith(".csv"):
                file_directory = os.path.join(directory, filename)
                lst_dislike.append(file_directory)
                pd.read_csv(file_directory)
                
                
            else:
                continue

# %%
loop_directory('C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5')

# %%
lst_dislike
# print(len(lst_dislike))
# Out:
# ['C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID100.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID93.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID94.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID95.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID96.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID97.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID98.csv',
#  'C:/Users/becha/Desktop/Face_meteor_analysis/Data/preprocessed_data_rating/preprocessed_data_rating/v5\\rating_GroupID99.csv']

# %%
datlst_dislike = []
for i in range(0, len(lst)):
    datlst_dislike.append("df_dislike" + str(i))
    globals()["df_dislike" + str(i)] = pd.read_csv(lst_dislike[i])
datlst_dislike
# Out:
# ['df_dislike0',
#  'df_dislike1',
#  'df_dislike2',
#  'df_dislike3',
#  'df_dislike4',
#  'df_dislike5',
#  'df_dislike6',
#  'df_dislike7',
#  'df_dislike8',
#  'df_dislike9',
#  'df_dislike10',
#  'df_dislike11',
#  'df_dislike12',
#  'df_dislike13',
#  'df_dislike14',
#  'df_dislike15',
#  'df_dislike16',
#  'df_dislike17',
#  'df_dislike18',
#  'df_dislike19',
#  'df_dislike20',
#  'df_dislike21',
#  'df_dislike22',
#  'df_dislike23',
#  'df_dislike24',
#  'df_dislike25',
#  'df_dislike26',
#  'df_dislike27',
#  'df_dislike28',
#  'df_dislike29',
#  'df_dislike30',
#  'df_dislike31',
#  'df_dislike32',
#  'df_dislike33',
#  'df_dislike34',
#  'df_dislike35',
#  'df_dislike36',
#  'df_dislike37',
#  'df_dislike38',
#  'df_dislike39',
#  'df_dislike40',
#  'df_dislike41',
#  'df_dislike42',
#  'df_dislike43',
#  'df_dislike44',
#  'df_dislike45',
#  'df_dislike46',
#  'df_dislike47',
#  'df_dislike48',
#  'df_dislike49',
#  'df_dislike50',
#  'df_dislike51']

# %% [markdown]
# # The correlation between round 10 and dislike

# %% [markdown]
# ## The performance of the dictator in round 10

# %%
## 取round 10的島主的pgg_receive
dictator_pgg = []
for i in range(0, len(lst)):
    dictator_pgg.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[9]['pgg_receive'])

# print(dictator_pgg)
# print(len(dictator_pgg))

# %%
## 取round 10的所有人的pgg_receive
all_pgg = []
for i in range(0,len(lst)):
    all_pgg.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 10]['pgg_receive']))

# print(all_pgg)
# print(len(all_pgg))

# %%
# 計算：v5中島主最後一round pgg表現的顯著程度
ratio_10 = [x/y for x, y in zip(dictator_pgg, all_pgg)]

# %%
df_ratio = pd.DataFrame({"group": datlst, "dictator's pgg receive": dictator_pgg, "all player's pgg receive": all_pgg, "ratio": ratio_10})

# %%
df_ratio
# Out:
#    group  dictator's pgg receive  all player's pgg receive     ratio
# 0    df0                     207                       530  0.390566
# 1    df1                     152                       656  0.231707
# 2    df2                     224                       360  0.622222
# 3    df3                     198                       500  0.396000
# 4    df4                     320                       320  1.000000
# 5    df5                     463                       466  0.993562
# 6    df6                     305                       550  0.554545
# 7    df7                     230                       780  0.294872
# 8    df8                     200                       500  0.400000
# 9    df9                     205                       760  0.269737
# 10  df10                     450                       450  1.000000
# 11  df11                     205                       780  0.262821
# 12  df12                     350                       350  1.000000
# 13  df13                     200                       500  0.400000
# 14  df14                     800                       800  1.000000
# 15  df15                     200                       400  0.500000
# 16  df16                     300                       800  0.375000
# 17  df17                       0                       400  0.000000
# 18  df18                     269                       740  0.363514
# 19  df19                     250                       400  0.625000
# 20  df20                     200                       700  0.285714
# 21  df21                     255                       620  0.411290
# 22  df22                     310                       310  1.000000
# 23  df23                     200                       800  0.250000
# 24  df24                     199                       800  0.248750
# 25  df25                     200                       800  0.250000
# 26  df26                     405                       700  0.578571
# 27  df27                     170                       536  0.317164
# 28  df28                     510                       510  1.000000
# 29  df29                     200                       500  0.400000
# 30  df30                     270                       566  0.477032
# 31  df31                     200                       200  1.000000
# 32  df32                     200                       800  0.250000
# 33  df33                     327                       454  0.720264
# 34  df34                     130                       420  0.309524
# 35  df35                     464                       496  0.935484
# 36  df36                     300                       400  0.750000
# 37  df37                     200                       800  0.250000
# 38  df38                     238                       676  0.352071
# 39  df39                     201                       800  0.251250
# 40  df40                     486                       486  1.000000
# 41  df41                     700                       700  1.000000
# 42  df42                      31                       300  0.103333
# 43  df43                      76                       350  0.217143
# 44  df44                     215                       500  0.430000
# 45  df45                     560                       580  0.965517
# 46  df46                     233                       760  0.306579
# 47  df47                     200                       700  0.285714
# 48  df48                     118                       528  0.223485
# 49  df49                     250                       760  0.328947
# 50  df50                     200                       800  0.250000
# 51  df51                     250                       700  0.357143

# %% [markdown]
# ## The degree of dislike of the dictator

# %%
# 先以df_dislike0為例
dislike = []
for i in range(0,len(lst)):
    dislike.append(np.mean(globals()["df_dislike" + str(i)]['liking_p1'][1:]))

# print(dislike)
# len(dislike)

# %%
df_ratio['dislike'] = dislike

# %%
df_ratio
# Out:
#    group  dictator's pgg receive  all player's pgg receive     ratio  \
# 0    df0                     207                       530  0.390566
# 1    df1                     152                       656  0.231707
# 2    df2                     224                       360  0.622222
# 3    df3                     198                       500  0.396000
# 4    df4                     320                       320  1.000000
# 5    df5                     463                       466  0.993562
# 6    df6                     305                       550  0.554545
# 7    df7                     230                       780  0.294872
# 8    df8                     200                       500  0.400000
# 9    df9                     205                       760  0.269737
# 10  df10                     450                       450  1.000000
# 11  df11                     205                       780  0.262821
# 12  df12                     350                       350  1.000000
# 13  df13                     200                       500  0.400000
# 14  df14                     800                       800  1.000000
# 15  df15                     200                       400  0.500000
# 16  df16                     300                       800  0.375000
# 17  df17                       0                       400  0.000000
# 18  df18                     269                       740  0.363514
# 19  df19                     250                       400  0.625000
# 20  df20                     200                       700  0.285714
# 21  df21                     255                       620  0.411290
# 22  df22                     310                       310  1.000000
# 23  df23                     200                       800  0.250000
# 24  df24                     199                       800  0.248750
# 25  df25                     200                       800  0.250000
# 26  df26                     405                       700  0.578571
# 27  df27                     170                       536  0.317164
# 28  df28                     510                       510  1.000000
# 29  df29                     200                       500  0.400000
# 30  df30                     270                       566  0.477032
# 31  df31                     200                       200  1.000000
# 32  df32                     200                       800  0.250000
# 33  df33                     327                       454  0.720264
# 34  df34                     130                       420  0.309524
# 35  df35                     464                       496  0.935484
# 36  df36                     300                       400  0.750000
# 37  df37                     200                       800  0.250000
# 38  df38                     238                       676  0.352071
# 39  df39                     201                       800  0.251250
# 40  df40                     486                       486  1.000000
# 41  df41                     700                       700  1.000000
# 42  df42                      31                       300  0.103333
# 43  df43                      76                       350  0.217143
# 44  df44                     215                       500  0.430000
# 45  df45                     560                       580  0.965517
# 46  df46                     233                       760  0.306579
# 47  df47                     200                       700  0.285714
# 48  df48                     118                       528  0.223485
# 49  df49                     250                       760  0.328947
# 50  df50                     200                       800  0.250000
# 51  df51                     250                       700  0.357143
#
#        dislike
# 0    73.333333
# 1    31.333333
# 2    66.666667
# 3    53.666667
# 4     1.666667
# 5    20.333333
# 6    37.000000
# 7    93.000000
# 8    36.333333
# 9    77.666667
# 10   13.333333
# 11   44.000000
# 12    3.000000
# 13  100.000000
# 14   21.000000
# 15   60.000000
# 16   51.666667
# 17  100.000000
# 18   53.666667
# 19   25.333333
# 20   41.666667
# 21   61.666667
# 22    0.000000
# 23   96.666667
# 24   85.000000
# 25  100.000000
# 26    0.000000
# 27   68.333333
# 28   35.666667
# 29   37.000000
# 30   39.333333
# 31   25.000000
# 32   83.333333
# 33   13.333333
# 34   43.333333
# 35   50.000000
# 36   63.000000
# 37   73.333333
# 38   56.666667
# 39   47.666667
# 40   25.000000
# 41   11.333333
# 42   17.666667
# 43   60.000000
# 44   49.000000
# 45   17.666667
# 46   49.333333
# 47   85.666667
# 48   50.000000
# 49   63.000000
# 50   51.000000
# 51   53.666667

# %% [markdown]
# ## The correlation

# %%
my_rho = np.corrcoef(ratio_10, dislike)

# print(my_rho)
print("The value of correlation is",my_rho[0][1],'.')
# Out:
# The value of correlation is -0.6713841683147632 .

# %% [markdown]
# ## Visualization

# %%
ax = sns.regplot(x= ratio_10, y=dislike, data=df_ratio, ci=None)
ax.set_title("The score of being liked of the dictator vs. The pgg_receive in round 10")
ax.set_xlabel("The ratio of pgg_receive of the dictator in round 10")
ax.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 9 and dislike

# %% [markdown]
# ## The performance of the dictator in round 9

# %%
## 取round 9的島主的pgg_receive
dictator_pgg_9 = []
for i in range(0, len(lst)):
    dictator_pgg_9.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[8]['pgg_receive'])

# print(dictator_pgg_9)
# print(len(dictator_pgg_9))

# %%
## 取round 9的所有人的pgg_receive
all_pgg_9 = []
for i in range(0,len(lst)):
    all_pgg_9.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 9]['pgg_receive']))

# print(all_pgg_9)
# print(len(all_pgg_9))

# %%
# 計算：v5中島主round 9 pgg表現的顯著程度
ratio_9 = [x/y for x, y in zip(dictator_pgg_9, all_pgg_9)]
# type(ratio)

# %%
df_ratio_9 = pd.DataFrame({"group": datlst, "dictator's pgg receive": dictator_pgg_9, "all player's pgg receive": all_pgg_9, "ratio": ratio_9})

# %%
df_ratio_9['dislike'] = dislike

# %%
df_ratio_9
# Out:
#    group  dictator's pgg receive  all player's pgg receive     ratio  \
# 0    df0                     220                       710  0.309859
# 1    df1                     135                       508  0.265748
# 2    df2                     206                       430  0.479070
# 3    df3                     174                       500  0.348000
# 4    df4                      60                       210  0.285714
# 5    df5                     231                       642  0.359813
# 6    df6                     230                       600  0.383333
# 7    df7                     200                       700  0.285714
# 8    df8                     200                       480  0.416667
# 9    df9                     199                       800  0.248750
# 10  df10                     115                       460  0.250000
# 11  df11                     185                       640  0.289062
# 12  df12                     210                       580  0.362069
# 13  df13                     200                       800  0.250000
# 14  df14                     200                       730  0.273973
# 15  df15                     200                       700  0.285714
# 16  df16                     149                       800  0.186250
# 17  df17                     200                       800  0.250000
# 18  df18                     226                       796  0.283920
# 19  df19                     200                       800  0.250000
# 20  df20                     189                       732  0.258197
# 21  df21                     200                       730  0.273973
# 22  df22                     420                       420  1.000000
# 23  df23                     200                       800  0.250000
# 24  df24                     201                       800  0.251250
# 25  df25                     200                       800  0.250000
# 26  df26                     300                       770  0.389610
# 27  df27                     200                       622  0.321543
# 28  df28                     200                       740  0.270270
# 29  df29                     200                       670  0.298507
# 30  df30                     235                       608  0.386513
# 31  df31                     590                       590  1.000000
# 32  df32                     200                       800  0.250000
# 33  df33                     318                       436  0.729358
# 34  df34                     120                       420  0.285714
# 35  df35                     209                       660  0.316667
# 36  df36                     200                       600  0.333333
# 37  df37                     200                       600  0.333333
# 38  df38                     254                       630  0.403175
# 39  df39                     207                       700  0.295714
# 40  df40                     198                       532  0.372180
# 41  df41                     201                       800  0.251250
# 42  df42                     275                       454  0.605727
# 43  df43                     160                       580  0.275862
# 44  df44                     212                       700  0.302857
# 45  df45                     200                       600  0.333333
# 46  df46                     261                       790  0.330380
# 47  df47                     200                       680  0.294118
# 48  df48                     161                       680  0.236765
# 49  df49                     207                       800  0.258750
# 50  df50                     200                       800  0.250000
# 51  df51                     249                       790  0.315190
#
#        dislike
# 0    73.333333
# 1    31.333333
# 2    66.666667
# 3    53.666667
# 4     1.666667
# 5    20.333333
# 6    37.000000
# 7    93.000000
# 8    36.333333
# 9    77.666667
# 10   13.333333
# 11   44.000000
# 12    3.000000
# 13  100.000000
# 14   21.000000
# 15   60.000000
# 16   51.666667
# 17  100.000000
# 18   53.666667
# 19   25.333333
# 20   41.666667
# 21   61.666667
# 22    0.000000
# 23   96.666667
# 24   85.000000
# 25  100.000000
# 26    0.000000
# 27   68.333333
# 28   35.666667
# 29   37.000000
# 30   39.333333
# 31   25.000000
# 32   83.333333
# 33   13.333333
# 34   43.333333
# 35   50.000000
# 36   63.000000
# 37   73.333333
# 38   56.666667
# 39   47.666667
# 40   25.000000
# 41   11.333333
# 42   17.666667
# 43   60.000000
# 44   49.000000
# 45   17.666667
# 46   49.333333
# 47   85.666667
# 48   50.000000
# 49   63.000000
# 50   51.000000
# 51   53.666667

# %% [markdown]
# ## The correlation

# %%
my_rho_9 = np.corrcoef(ratio_9, dislike)

# print(my_rho)
print("The value of correlation is",my_rho_9[0][1],'.')
# Out:
# The value of correlation is -0.41276962504612164 .

# %% [markdown]
# ## Visualization

# %%
ax_9 = sns.regplot(x= ratio_9, y=dislike, data=df_ratio_9, ci=None)
ax_9.set_title("The score of being liked of the dictator vs. The pgg_receive in round 9")
ax_9.set_xlabel("The ratio of pgg_receive of the dictator in round 9")
ax_9.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 9 & 10 and dislike

# %% [markdown]
# ## The performance of the dictator in round 9 & 10

# %%
ratio_910 = [(x+y)/2 for x, y in zip(ratio_9, ratio_10)]

# %% [markdown]
# ## The correlation

# %%
my_rho_910 = np.corrcoef(ratio_910, dislike)

print("The value of correlation is",my_rho_910[0][1],'.')
# Out:
# The value of correlation is -0.69267288012138 .

# %% [markdown]
# # The correlation between round 1-8 and dislike

# %% [markdown]
# ## The performance of the dictator in round 1

# %%
# 取round 1的島主的pgg_receive
dictator_pgg_1 = []
for i in range(0, len(lst)):
    dictator_pgg_1.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[0]['pgg_receive'])

# print(dictator_pgg_1)

# %%
# 取round 1的所有人的pgg_receive
all_pgg_1 = []
for i in range(0,len(lst)):
    all_pgg_1.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 1]['pgg_receive']))

print(all_pgg_1)
# Out:
# [370, 270, 262, 230, 420, 328, 400, 400, 540, 464, 460, 560, 422, 430, 490, 444, 310, 490, 480, 200, 540, 390, 500, 340, 440, 720, 470, 240, 520, 470, 382, 330, 330, 450, 450, 500, 410, 364, 440, 360, 436, 410, 320, 488, 290, 494, 500, 472, 480, 660, 440, 388]

# %%
# 計算：島主在round 1中pgg表現的顯著程度
ratio_1 = [x/y for x, y in zip(dictator_pgg_1, all_pgg_1)]

# %% [markdown]
# ## The performance of the dictator in round 2

# %%
# 取round 2的島主的pgg_receive
dictator_pgg_2 = []
for i in range(0, len(lst)):
    dictator_pgg_2.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[1]['pgg_receive'])
# print(dictator_pgg_2)

# %%
# 取round 2的所有人的pgg_receive
all_pgg_2 = []
for i in range(0,len(lst)):
    all_pgg_2.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 2]['pgg_receive']))

# print(all_pgg_2)

# %%
# 計算：島主在round 2中pgg表現的顯著程度
ratio_2 = [x/y for x, y in zip(dictator_pgg_2, all_pgg_2)]

# %% [markdown]
# ## The performance of the dictator in round 3

# %%
# 取round 3的島主的pgg_receive
dictator_pgg_3 = []
for i in range(0, len(lst)):
    dictator_pgg_3.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[2]['pgg_receive'])
# print(dictator_pgg_3)

# %%
# 取round 3的所有人的pgg_receive
all_pgg_3 = []
for i in range(0,len(lst)):
    all_pgg_3.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 3]['pgg_receive']))

# print(all_pgg_3)

# %%
# 計算：島主在round 3中pgg表現的顯著程度
ratio_3 = [x/y for x, y in zip(dictator_pgg_3, all_pgg_3)]

# %% [markdown]
# ## The performance of the dictator in round 4

# %%
# 取round 4的島主的pgg_receive
dictator_pgg_4 = []
for i in range(0, len(lst)):
    dictator_pgg_4.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[3]['pgg_receive'])
# print(dictator_pgg_4)

# %%
# 取round 4的所有人的pgg_receive
all_pgg_4 = []
for i in range(0,len(lst)):
    all_pgg_4.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 4]['pgg_receive']))

# print(all_pgg_4)

# %%
# 計算：島主在round 4中pgg表現的顯著程度
ratio_4 = [x/y for x, y in zip(dictator_pgg_4, all_pgg_4)]

# %% [markdown]
# ## The performance of the dictator in round 5

# %%
# 取round 5的島主的pgg_receive
dictator_pgg_5 = []
for i in range(0, len(lst)):
    dictator_pgg_5.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[4]['pgg_receive'])
# print(dictator_pgg_5)

# %%
# 取round 5的所有人的pgg_receive
all_pgg_5 = []
for i in range(0,len(lst)):
    all_pgg_5.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 5]['pgg_receive']))

# print(all_pgg_5)

# %%
# 計算：島主在round 5中pgg表現的顯著程度
ratio_5 = [x/y for x, y in zip(dictator_pgg_5, all_pgg_5)]

# %% [markdown]
# ## The performance of the dictator in round 6

# %%
# 取round 6的島主的pgg_receive
dictator_pgg_6 = []
for i in range(0, len(lst)):
    dictator_pgg_6.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[5]['pgg_receive'])
# print(dictator_pgg_6)

# %%
# 取round 6的所有人的pgg_receive
all_pgg_6 = []
for i in range(0,len(lst)):
    all_pgg_6.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 6]['pgg_receive']))

# print(all_pgg_6)

# %%
# 計算：島主在round 6中pgg表現的顯著程度
ratio_6 = [x/y for x, y in zip(dictator_pgg_6, all_pgg_6)]

# %% [markdown]
# ## The performance of the dictator in round 7

# %%
# 取round 7的島主的pgg_receive
dictator_pgg_7 = []
for i in range(0, len(lst)):
    dictator_pgg_7.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[6]['pgg_receive'])
# print(dictator_pgg_7)

# %%
# 取round 7的所有人的pgg_receive
all_pgg_7 = []
for i in range(0,len(lst)):
    all_pgg_7.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 7]['pgg_receive']))

# print(all_pgg_7)

# %%
# 計算：島主在round 7中pgg表現的顯著程度
ratio_7 = [x/y for x, y in zip(dictator_pgg_7, all_pgg_7)]

# %% [markdown]
# ## The performance of the dictator in round 8

# %%
# 取round 8的島主的pgg_receive
dictator_pgg_8 = []
for i in range(0, len(lst)):
    dictator_pgg_8.append(globals()['df'+str(i)][globals()['df'+str(i)]['dictator'] == 1].iloc[7]['pgg_receive'])
# print(dictator_pgg_8)

# %%
# 取round 8的所有人的pgg_receive
all_pgg_8 = []
for i in range(0,len(lst)):
    all_pgg_8.append(sum(globals()["df" + str(i)][globals()["df" + str(i)]['round'] == 8]['pgg_receive']))

# print(all_pgg_8)

# %%
# 計算：島主在round 8中pgg表現的顯著程度
ratio_8 = [x/y for x, y in zip(dictator_pgg_8, all_pgg_8)]

# %% [markdown]
# ## The performance of the dictator in round 1-8

# %%
df_RD = pd.DataFrame({"group": datlst, "round 1": ratio_1, "round 2": ratio_2, "round 3": ratio_3, "round 4": ratio_4, "round 5": ratio_5, "round 6": ratio_6, "round 7": ratio_7, "round 8": ratio_8})

# %%
mean_RD = []
mean_RD = df_RD[['round 1', 'round 2', 'round 3', 'round 4', 'round 5', 'round 6', 'round 7', 'round 8']].mean(1)

# %%
mean_RD
# Out:
# 0     0.344635
# 1     0.264007
# 2     0.367081
# 3     0.319701
# 4     0.255579
# 5     0.407289
# 6     0.399406
# 7     0.249510
# 8     0.295497
# 9     0.248933
# 10    0.267100
# 11    0.292697
# 12    0.443102
# 13    0.302037
# 14    0.332621
# 15    0.334876
# 16    0.296185
# 17    0.282947
# 18    0.309118
# 19    0.337082
# 20    0.248665
# 21    0.291266
# 22    0.492104
# 23    0.269769
# 24    0.346378
# 25    0.239583
# 26    0.413204
# 27    0.286505
# 28    0.294507
# 29    0.214046
# 30    0.369450
# 31    0.404235
# 32    0.272001
# 33    0.503854
# 34    0.259760
# 35    0.374229
# 36    0.294772
# 37    0.246931
# 38    0.461880
# 39    0.296330
# 40    0.403089
# 41    0.290448
# 42    0.338153
# 43    0.293016
# 44    0.319520
# 45    0.339062
# 46    0.332232
# 47    0.238796
# 48    0.242446
# 49    0.317131
# 50    0.254086
# 51    0.334888
# dtype: float64

# %% [markdown]
# ## The correlation

# %%
df_cor = pd.DataFrame({"ratio of round 1-8":mean_RD,"dislike":dislike})

# %%
# df_cor

# %%
my_rho_1to8 = np.corrcoef(mean_RD, dislike)

# print(my_rho)
print("The value of correlation is",my_rho_1to8[0][1],'.')
# Out:
# The value of correlation is -0.46825651543807745 .

# %% [markdown]
# ## Visualization

# %%
ax_1to8 = sns.regplot(x= mean_RD, y=dislike, data=df_cor, ci=None)
ax_1to8.set_title("The score of being liked of the dictator vs. The pgg_receive in round 1-8")
ax_1to8.set_xlabel("The ratio of pgg_receive of the dictator in round 1-8")
ax_1to8.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 1-10 and dislike

# %%
ratio_1to10 = [(x*8+y*2)/10 for x, y in zip(mean_RD, ratio_910)]

# %%
ratio_1to10
# Out:
# [0.34575033465145727,
#  0.26095135481361853,
#  0.40379372236625927,
#  0.3301610057444275,
#  0.3330347543272628,
#  0.4611684784096644,
#  0.4133126061899062,
#  0.25766628024692545,
#  0.31806407544125054,
#  0.25099507804657534,
#  0.3386799013216212,
#  0.2893457547320099,
#  0.49068852043499345,
#  0.3066294730248219,
#  0.39349434038074876,
#  0.34647210768950654,
#  0.29307267100388545,
#  0.25135745207173776,
#  0.3120374302904353,
#  0.3571652362274257,
#  0.2533232300804886,
#  0.3015391681111491,
#  0.593683405292926,
#  0.2658152734778122,
#  0.32710204694263595,
#  0.24166666666666664,
#  0.42738165287925317,
#  0.2930744281439746,
#  0.3626323472224841,
#  0.24108717878379676,
#  0.3819142914616891,
#  0.5233878931505952,
#  0.2676005580097652,
#  0.5480453715871482,
#  0.267331793466686,
#  0.4245979210419197,
#  0.34415085817524843,
#  0.2558779403385919,
#  0.4450282100631724,
#  0.29176024581617915,
#  0.4596891788786661,
#  0.3574835746039701,
#  0.3414281602897642,
#  0.2837131867486533,
#  0.32890201623931936,
#  0.4011349887964313,
#  0.329481072779542,
#  0.24902009928732943,
#  0.2399818921070634,
#  0.3124742327837756,
#  0.2532689393939394,
#  0.3351435165543867]

# %% [markdown]
# ## The correlation

# %%
my_rho_1to10 = np.corrcoef(ratio_1to10, dislike)

# print(my_rho)
print("The value of correlation is",my_rho_1to10[0][1],'.')
# Out:
# The value of correlation is -0.618631233192099 .

# %% [markdown]
# ##  Visualization

# %%
df_1to10 = pd.DataFrame({"round 1-10": ratio_1to10, "dislike":dislike})

# %%
ax_1to10 = sns.regplot(x= ratio_1to10, y=dislike, data=df_1to10, ci=None)
ax_1to10.set_title("The score of being liked of the dictator vs. The pgg_receive in round 1-10")
ax_1to10.set_xlabel("The ratio of pgg_receive of the dictator in round 1-10")
ax_1to10.set_ylabel("The score of being liked of the dictator")
# Out:
# Text(0, 0.5, 'The score of being liked of the dictator')

# %% [markdown]
# # The correlation between round 10 and round 1-8

# %% [markdown]
# ## The correlation

# %%
rho = np.corrcoef(ratio_10, mean_RD)

# print(my_rho)
print("The value of correlation is",rho[0][1],'.')
# Out:
# The value of correlation is 0.48069996330356507 .

# %% [markdown]
# ## Visualization

# %%
dat = pd.DataFrame({'round 1-8': mean_RD, 'round 10': ratio_10})

# %%
plt = sns.regplot(x = mean_RD, y = ratio_10, data=dat, ci=None)
plt.set_xlabel("The ratio of pgg_receive of the dictator in round 1-8")
plt.set_ylabel("The ratio of pgg_receive of the dictator in round 10")
# Out:
# Text(0, 0.5, 'The ratio of pgg_receive of the dictator in round 10')
